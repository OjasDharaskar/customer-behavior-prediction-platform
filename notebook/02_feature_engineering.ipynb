# %%
from pathlib import Path
from src.features.features import generate_features

# Paths are now relative to wherever you launch Jupyter
df_features = generate_features(
    clean_path="../data/Interim/(INTERIM)online_retail_II.csv",
    returns_path="../data/Interim/return_online_retail_II.csv",
    cutoff_date="2011-09-10",
    save_path="../data/processed/(PROC)online_retail_II.csv"
)

df_features.head()
# Out:
# Features and targets exported to ../data/processed/(PROC)online_retail_II.csv
#    customer_id  recency  frequency  monetary_total  monetary_avg  \
# 0      13085.0       66         10          485.64     48.564000
# 1      13078.0        9         79        22112.19    279.901139
# 2      15362.0      357          2          613.08    306.540000
# 3      18102.0        7        120       435567.63   3629.730250
# 4      12682.0        9         42        18714.12    445.574286
#
#    avg_basket_size  purchase_frequency_trend  variance_purchase_intervals  \
# 0        72.600000                       0.0                  7233.194444
# 1       109.594937                       2.0                    43.581752
# 2       184.000000                       0.0                     0.000000
# 3      1221.116667                       0.0                    81.430423
# 4       201.904762                       3.0                   129.974390
#
# ...

# %%
df_features.shape
# Out:
# (5346, 26)
